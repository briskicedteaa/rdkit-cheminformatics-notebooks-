# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Acetylcholinesterase-QSAR-ML-/blob/main/03_Molecular_Fingerprints_and_Similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
from rdkit import Chem
import pandas as pd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 35.6 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv('/content/Ligand.csv')

df
# Out:
#         Compound                                         SMILES
# 0      Caffeine                      Cn1c(=O)c2c(ncn2C)n(C)c1=O
# 1        Aspirin                          CC(=O)Oc1ccccc1C(=O)O
# 2  Acetaminophen                          CC(=O)NC1=CC=C(C=C1)O
# 3     Ibuprofen                   CC(C)CC1=CC=C(C=C1)C(C)C(=O)O
# 4      Nicotine                            CN1CCC[C@H]1c2cccnc2
# 5       Dopamine                              NCCc1ccc(O)c(O)c1
# 6      Serotonin                         NCCc1c[nH]c2ccc(O)cc12
# 7    Cholesterol  CC(C)CCCC(C)C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C
# 8        Ethanol                                            CCO
# 9  Invalid Entry                                           C1CC

# %%
for index, row in df.iterrows():
  compound_name = row['Compound']
  smiles_string = row['SMILES']
  mol = Chem.MolFromSmiles(smiles_string)

display(df)
# Out:
# [21:54:57] SMILES Parse Error: unclosed ring for input: 'C1CC'
#         Compound                                         SMILES
# 0      Caffeine                      Cn1c(=O)c2c(ncn2C)n(C)c1=O
# 1        Aspirin                          CC(=O)Oc1ccccc1C(=O)O
# 2  Acetaminophen                          CC(=O)NC1=CC=C(C=C1)O
# 3     Ibuprofen                   CC(C)CC1=CC=C(C=C1)C(C)C(=O)O
# 4      Nicotine                            CN1CCC[C@H]1c2cccnc2
# 5       Dopamine                              NCCc1ccc(O)c(O)c1
# 6      Serotonin                         NCCc1c[nH]c2ccc(O)cc12
# 7    Cholesterol  CC(C)CCCC(C)C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C
# 8        Ethanol                                            CCO
# 9  Invalid Entry                                           C1CC
