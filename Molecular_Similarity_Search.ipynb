# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/rdkit-cheminformatics-notebooks-/blob/main/Molecular_Similarity_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
from rdkit import Chem
import pandas as pd
# Out:
# Collecting rdkit
#   Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl (37.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 47.5 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2026.3.4

# %%
df = pd.read_csv('/content/File1.csv')

df
# Out:
#       Molecule ChEMBL ID;"Molecule Name";"Molecule Max Phase";"Molecular Weight";"#RO5 Violations";"AlogP";"Compound Key";"Smiles";"Standard Type";"Standard Relation";"Standard Value";"Standard Units";"pChEMBL Value";"Data Validity Comment";"Comment";"Uo Units";"Ligand Efficiency BEI";"Ligand Efficiency LE";"Ligand Efficiency LLE";"Ligand Efficiency SEI";"Potential Duplicate";"Assay ChEMBL ID";"Assay Description";"Assay Type";"BAO Format ID";"BAO Label";"Assay Organism";"Assay Tissue ChEMBL ID";"Assay Tissue Name";"Assay Cell Type";"Assay Subcellular Fraction";"Assay Parameters";"Assay Variant Accession";"Assay Variant Mutation";"Target ChEMBL ID";"Target Name";"Target Organism";"Target Type";"Document ChEMBL ID";"Source ID";"Source Description";"Document Journal";"Document Year";"Cell ChEMBL ID";"Properties";"Action Type";"Standard Text Value";"Value"  \
# 0      CHEMBL64011;"";"None";"472.67";"0";"4.21";"7h"...
# 1      CHEMBL296429;"";"None";"316.85";"0";"2.40";"1v...
# 2          CHEMBL238977;"";"None";"458.15";"0";"0.43";"7
# 3      CHEMBL1644317;"";"None";"403.12";"0";"1.16";"8...
# 4      CHEMBL1644320;"";"None";"453.18";"0";"2.31";"1...
# ...                                                  ...
# 20127  CHEMBL6172894;"";"None";"347.41";"0";"3.42";"6...
# 20128  CHEMBL6148088;"";"None";"539.81";"2";"7.45";"5...
# 20129  CHEMBL6170242;"";"None";"479.58";"1";"5.82";"N...
# 20130  CHEMBL6166382;"";"None";"329.48";"0";"4.65";"4...
# 20131  CHEMBL6148509;"";"None";"455.41";"1";"5.43";"4...
#
#                                               Unnamed: 1 Unnamed: 2  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2       K203";"NC(=O)c1cc[n+](C/C=C/C[n+]2ccc(/C=N/O)...        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 20127                                                NaN        NaN
# 20128                                                NaN        NaN
# 20129                                                NaN        NaN
# 20130                                                NaN        NaN
# 20131                                                NaN        NaN
#
#       Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0            NaN        NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 20127        NaN        NaN        NaN        NaN        NaN        NaN
# 20128        NaN        NaN        NaN        NaN        NaN        NaN
# 20129        NaN        NaN        NaN        NaN        NaN        NaN
# 20130        NaN        NaN        NaN        NaN        NaN        NaN
# 20131        NaN        NaN        NaN        NaN        NaN        NaN
#
#       Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 20127        NaN         NaN         NaN         NaN         NaN         NaN
# 20128        NaN         NaN         NaN         NaN         NaN         NaN
# 20129        NaN         NaN         NaN         NaN         NaN         NaN
# 20130        NaN         NaN         NaN         NaN         NaN         NaN
# 20131        NaN         NaN         NaN         NaN         NaN         NaN
#
# [20132 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Molecule ChEMBL ID;"Molecule Name";"Molecule Max Phase";"Molecular Weight";"#RO5 Violations";"AlogP";"Compound Key";"Smiles";"Standard Type";"Standard Relation";"Standard Value";"Standard Units";"pChEMBL Value";"Data Validity Comment";"Comment";"Uo Units";"Ligand Efficiency BEI";"Ligand Efficiency LE";"Ligand Efficiency LLE";"Ligand Efficiency SEI";"Potential Duplicate";"Assay ChEMBL ID";"Assay Description";"Assay Type";"BAO Format ID";"BAO Label";"Assay Organism";"Assay Tissue ChEMBL ID";"Assay Tissue Name";"Assay Cell Type";"Assay Subcellular Fraction";"Assay Parameters";"Assay Variant Accession";"Assay Variant Mutation";"Target ChEMBL ID";"Target Name";"Target Organism";"Target Type";"Document ChEMBL ID";"Source ID";"Source Description";"Document Journal";"Document Year";"Cell ChEMBL ID";"Properties";"Action Type";"Standard Text Value";"Value"',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')
