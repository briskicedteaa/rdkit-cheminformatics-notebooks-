# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/rdkit-cheminformatics-notebooks-/blob/main/Molecular_Similarity_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
from rdkit import Chem
import pandas as pd
# Out:
# Collecting rdkit
#   Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl (37.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 47.5 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2026.3.4

# %%
df = pd.read_csv('/content/File.csv', sep=';')
df = df.drop(columns=df.columns.difference(['Molecule Name', 'Smiles']))
df
# Out:
#       Molecule Name                                             Smiles
# 0               NaN  CN1CC[C@@]2(C)c3cc(OC(=O)NCCCCCCCCCN4CCOCC4)cc...
# 1               NaN       Cc1ccc(C(=O)/C(=N/O)SCC[N+](C)(C)C)cc1.[Cl-]
# 2               NaN  NC(=O)c1cc[n+](C/C=C/C[n+]2ccc(/C=N/O)cc2)cc1....
# 3               NaN      O/N=C/c1cc[n+](CCC[n+]2ccccc2)cc1.[Br-].[Br-]
# 4               NaN  O/N=C/c1cc[n+](CCC[n+]2ccc3ccccc3c2)cc1.[Br-]....
# ...             ...                                                ...
# 20127           NaN  CC1=CC(=O)[C@@](C)(O)C(=O)/C1=C\Nc1ccc(Cc2cccc...
# 20128           NaN  COc1cc2c(cc1OCCCCCC1CCSS1)C(=O)C(CC1CCN(Cc3ccc...
# 20129           NaN  C#CCCCOc1c(CN2CCc3ccccc3C2)cc(-c2cc(=O)c3ccccc...
# 20130           NaN              O=C(CCC1CCN(CC2CCCCC2)CC1)c1ccc(O)cc1
# 20131           NaN     COc1c(C(=O)CCC2CCN(CC3CCCCC3)CC2)cc(F)c(N)c1Br
#
# [20132 rows x 2 columns]
